# %%
a = list(map(int,(input("Enter 1st List").split())))
b =  list(map(int,(input("Enter 2nd List").split())))
c = a+b
print(type(c))
c.sort()
print(f"The 1st and 2nd list in marge and an acciding order {c}")
# Out:
# Enter 1st List 23 44 21 11
# Enter 2nd List 55 44 25 1123
# <class 'list'>
# The 1st and 2nd list in marge and an acciding order [11, 21, 23, 25, 44, 44, 55, 1123]

# %%
n = tuple(map(int,(input("Enter a number").split())))
even = ()
odd = ()
for i in n:
    if (i % 2 == 0):
        even = even +(i,)
    else:
        odd = odd +(i,)
even = tuple(sorted(even))
odd = tuple(sorted(odd))
print(f"the all Even number is this: {even}")
print(f"The all odd number is this:{odd}")
# Out:
# Enter a number 232 22 12 321
# the all Even number is this: (12, 22, 232)
# The all odd number is this:(321,)

# %%
student = {}

while True:
    print("A = Add a Student")
    print("B = Update Marks")
    print("C = Search for a Student")
    print("D = Display all Student and marks")
    print("E = Exit")

    choice = input("Enter your Choice").upper()

    if (choice == 'A'):
        name = input("Enter Student Name:")
        marks = int(input("Enter Marks"))
        student[name] = marks

    elif (choice == 'B'):
        name = input("Enter Student Name:")
        if (name in student):
            marks = int(input("Enter Student Marks"))
            student[name] = marks
        else:
            print("Student not found")

    elif (choice == 'C'):
        name = input("Enter Student Name:")
        if (name in student):
            print("Marks:", student[name])
        else:
            print("Student not found")

    elif (choice == 'D'):
        print("Student and Marks:")
        for name, marks in student.items():
            print(name, ":", marks)

    elif (choice == 'E'):
        break

    else:
        print("Invalid choice")
# Out:
# A = Add a Student
# B = Update Marks
# C = Search for a Student
# D = Display all Student and marks
# E = Exit

# %%
words = ["apple","banana","kiwi","cherry","mango"]
length_dict ={}
for word in words:
    length_dict[word]= len(word)
print(length_dict)
