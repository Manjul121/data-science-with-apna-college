# %% [markdown]
# ### AssignmentProblems1

# %% [raw]
# Q1. Write a program that asks the user for their name and age,then print sentence
#  like:
# Hello Shradha, you are 21 years old!

# %%
name = input("Enter your name ")
age = int(input("Enter your age:"))
print("Hello", name, ",", "you are", age, "years old!")
# Out:
# Enter your name  Manjul
# Enter your age: 22
# Hello Manjul , you are 22 years old!

# %% [markdown]
# Q2. Take two numbers as input from the user and print their sum, difference product,and quotient.

# %%
a = float(input( "Enter the 1st nums :"))
b = float(input("Enter the 2nd nums : "))
print ("the sum of a and b is :",a+b)
print ("the difference of a and b is :",a-b)
print ("the product of a and b is :",a*b)
print ("the quotient of a and b is :",a/b)
# Out:
# Enter the 1st nums : 10
# Enter the 2nd nums :  5
# the sum of a and b is : 15.0
# the difference of a and b is : 5.0
# the product of a and b is : 50.0
# the quotient of a and b is : 2.0

# %% [markdown]
# Q3. Ask the user to enter two integers and one float. Convert them all to floats and print their average.

# %%
a = int(input("Enter the 1st nums :"))
b = int(input("Enter the 2nd nums :"))
c = float(input("Enter the 3rd nums :"))
a = float(a)
b = float(b)
print(type(a))
print(type(b))
avg = (a+b+c)/3
print("the avg of a , b and c is :", avg )
# Out:
# Enter the 1st nums : 12
# Enter the 2nd nums : 21
# Enter the 3rd nums : 23
# <class 'float'>
# <class 'float'>
# the avg of a , b and c is : 18.666666666666668

# %% [raw]
# Q4.The user enters a string containing a number (e.g."45").
# Convert it to :
# an integer
# a float
# a string again
# print all three value with their types.

# %%
a = input("Enter the nums")
a = int(a)
print(a,(type(a)))
a = float(a)
print(a,(type(a)))
a = str(a)
print(a,(type(a)))
# Out:
# Enter the nums 44
# 44 <class 'int'>
# 44.0 <class 'float'>
# 44.0 <class 'str'>

# %% [raw]
# Q5. Evanluate and print the result of the following expression:
# x = 10 + 3 * 2 **2
# based on what you learnt in the lecture explain why the output is what it is :

# %%
x = 10 + 3 * 2 **2
print(x)
# high precdence **
# 2**2 = 4
# secound high precedence *
# 3*4 = 12
#low precedence +
# 10 + 12 =22
# Out:
# 22

# %% [raw]
# Q6. Write a program to swap value of two number entered by user.

# %%
a = int(input("Enter first number"))
b = int(input ("Enter secound number"))
temp = a 
a = b
b =temp
print("after swaping")
print("First number:",a)
print("Secound number:",b)
# Out:
# Enter first number 12
# Enter secound number 21
# after swaping
# First number: 21
# Secound number: 12

# %% [raw]
# Q7. Ask the user for a temperature in Calsius (string input).
#     Convert it to float, then calculate and print temperature in fahrenheit.
#     conversion formula = Fahrenheit_temp = (calsius*(9/5))+32

# %%
calsius = float(input("Enter the Calsius:"))
f_t = (calsius*(9/5)) + 32
print("The F_Temp is this:",f_t)
# Out:
# Enter the Calsius: 22
# The F_Temp is this: 71.6

# %% [raw]
# Q8. Take the radius (r) as user input and print the area .
# use the formula: area = π*r2(value of π = 3.14)

# %%
radius = float(input("Enter the radius:"))
pi = 3.14
area = pi * radius ** 2
print ("The area of the circle is :",area)
# Out:
# Enter the radius: 55
# The area of the circle is : 9498.5

# %% [raw]
# Q9. Ask the user for : principal (P), Rate(R), Time(T).
#     Convert all to Float and compute simple interest:
# SI = (P*R*T) / 100

# %%
P = input ("Enter the princpal of simple interest:")
R = input ("Enter the rate:")
T = input ("Enter the time:")
P = float(P)
R = float(R)
T = float(T)
SI = (P*R*T) / 100
print("The total simple interest is this:",SI)
# Out:
# Enter the princpal of simple interest: 1200
# Enter the rate: 12
# Enter the time: 1
# The total simple interest is this: 144.0

# %% [raw]
# Q10. Take a decimal number as input (like 45.78)and output is.
# integer part = 45
# fractional part = .78

# %%
nums = float(input("Enter a number:"))
int_part = int(nums)
fract_part = nums - int_part
print("Integer_part:",int_part)
print("Fractional_part:",fract_part)
# Out:
# Enter a number: 12.55
# Integer_part: 12
# Fractional_part: 0.5500000000000007
